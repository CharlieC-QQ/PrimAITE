# %% [markdown]
# # Train a Single agent system using RLLib
#
# © Crown-owned copyright 2025, Defence Science and Technology Laboratory UK
#
# This notebook demonstrates how to use the ``PrimaiteRayEnv`` to train a basic PPO agent on the [UC2 scenario](./Data-Manipulation-E2E-Demonstration.ipynb).

# %%
# !primaite setup
# Out:
# 2025-03-21 11:09:20,240: Performing the PrimAITE first-time setup...
# 2025-03-21 11:09:20,240: Building the PrimAITE app directories...
# 2025-03-21 11:09:20,240: Building primaite_config.yaml...
# 2025-03-21 11:09:20,240: Rebuilding the demo notebooks...
# 2025-03-21 11:09:20,262: Rebuilding the example notebooks...
# 2025-03-21 11:09:20,264: PrimAITE setup complete!

# %%
import yaml
import ray
from primaite.config.load import data_manipulation_config_path
from primaite.session.ray_envs import PrimaiteRayEnv
from ray.rllib.algorithms.ppo import PPOConfig

# If you get an error saying this config file doesn't exist, you may need to run `primaite setup` in your command line
# to copy the files to your user data path.
with open(data_manipulation_config_path(), 'r') as f:
    cfg = yaml.safe_load(f)

ray.init(local_mode=True)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742555361.150294    7143 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742555361.154666    7143 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1742555361.166751    7143 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742555361.166770    7143 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742555361.166772    7143 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742555361.166773    7143 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-03-21 11:09:30,111	INFO worker.py:1788 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.16', ray_version='2.32.0', ray_commit='607f2f30f5f21543b6a5568ee77ea779eeba30a8')

# %% [markdown]
# #### Create a Ray algorithm and pass it our config.

# %%
for agent in cfg['agents']:
    if agent["ref"] == "defender":
        agent['agent_settings']['flatten_obs'] = True
env_config = cfg

config = (
    PPOConfig()
    .environment(env=PrimaiteRayEnv, env_config=env_config)
    .env_runners(num_env_runners=0)
    .training(train_batch_size=128)
    .evaluation(evaluation_duration=1)
)

# %% [markdown]
# #### Start the training

# %%
algo = config.build()
results = algo.train()
# Out:
# /opt/hostedtoolcache/Python/3.10.16/x64/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:516: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /opt/hostedtoolcache/Python/3.10.16/x64/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /opt/hostedtoolcache/Python/3.10.16/x64/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /opt/hostedtoolcache/Python/3.10.16/x64/lib/python3.10/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2025-03-21 11:09:31,280: PrimaiteGymEnv RNG seed = None
# 2025-03-21 11:09:32,580: Resetting environment, episode 0, avg. reward: 0.0
# 2025-03-21 11:09:32,582: Saving agent action log to /home/runner/primaite/4.0.0/sessions/2025-03-21/11-09-25/agent_actions/episode_0.json
# 2025-03-21 11:09:33,864: Resetting environment, episode 1, avg. reward: -82.70000000000002
# 2025-03-21 11:09:33,866: Saving agent action log to /home/runner/primaite/4.0.0/sessions/2025-03-21/11-09-25/agent_actions/episode_1.json
# 2025-03-21 11:09:34,128	WARNING deprecation.py:50 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!

# %% [markdown]
# ### Evaluate the results

# %%
eval = algo.evaluate()
# Out:
# 2025-03-21 11:09:35,688: Resetting environment, episode 2, avg. reward: -16.399999999999974
# 2025-03-21 11:09:35,689: Saving agent action log to /home/runner/primaite/4.0.0/sessions/2025-03-21/11-09-25/agent_actions/episode_2.json
